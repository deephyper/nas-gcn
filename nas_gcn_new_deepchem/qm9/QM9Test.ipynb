# %%
from nas_gcn.esol.load_data import load_data
(X_train, y_train), (X_valid, y_valid) = load_data(test=False, seed=2020)
# Out:
# Stage 1
# Stage 2
# 56 69 75 14
# (125, 14)
# [[  0.   2.]
#  [  0.  29.]
#  [  0.  31.]
#  [  0.  33.]
#  [  0.  40.]
#  [  0.  43.]
#  [  0.  52.]
#  [  0.  53.]
#  [  0.  62.]
#  [  0.  85.]
#  [  0.  86.]
#  [  0.  94.]
#  [  0. 104.]
#  [  0. 108.]
#  [  0. 117.]
#  [  0. 124.]
#  [  0. 150.]
#  [  0. 165.]
#  [  0. 170.]
#  [  0. 181.]
#  [  0. 196.]
#  [  0. 207.]
#  [  0. 208.]
#  [  0. 215.]
#  [  0. 218.]
#  [  0. 221.]
#  [  0. 242.]
#  [  0. 261.]
#  [  0. 262.]
#  [  0. 279.]
#  [  0. 284.]
#  [  0. 310.]
#  [  0. 316.]
#  [  0. 319.]
#  [  0. 329.]
#  [  0. 335.]
#  [  0. 337.]
#  [  0. 345.]
#  [  0. 356.]
#  [  0. 370.]
#  [  0. 393.]
#  [  0. 395.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]
#  [ 55.  55.]]
# 42
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-22808d5216f8> in <module>
#       1 from nas_gcn.esol.load_data import load_data
# ----> 2 (X_train, y_train), (X_valid, y_valid) = load_data(test=False, seed=2020)
#
# d:\nas-gcn\nas_gcn\esol\load_data.py in load_data(test, seed)
#      26
#      27     X_train, y_train, X_valid, y_valid, X_test, y_test, \
# ---> 28     tasks, transformers = load_molnet_data(func=FUNC,
#      29                                            featurizer=FEATURIZER,
#      30                                            split=SPLIT,
#
# d:\nas-gcn\nas_gcn\data_utils.py in load_molnet_data(func, featurizer, split, seed, MAX_ATOM, MAX_EDGE, N_FEAT, E_FEAT)
#     119     # TRAINING DATASET
#     120     for i in range(len(train_dataset)):
# --> 121         X, A, E, M, N = convert_data(train_x[i].nodes, train_x[i].pairs, MAX_ATOM, MAX_EDGE, N_FEAT, E_FEAT)
#     122         X_train.append(X)
#     123         E_train.append(E)
#
# d:\nas-gcn\nas_gcn\data_utils.py in convert_data(X, E, MAX_ATOM, MAX_EDGE, N_FEAT, E_FEAT)
#      44     print(Ao)
#      45     print(n_edge)
# ---> 46     Eo[:n_edge, :] = [e[a.row, a.col] for e, a in zip([E], [A])][0]
#      47
#      48     # Fill the zeros in Ao with self loop
#
# d:\nas-gcn\nas_gcn\data_utils.py in <listcomp>(.0)
#      44     print(Ao)
#      45     print(n_edge)
# ---> 46     Eo[:n_edge, :] = [e[a.row, a.col] for e, a in zip([E], [A])][0]
#      47
#      48     # Fill the zeros in Ao with self loop
#
# IndexError: index 29 is out of bounds for axis 1 with size 14
